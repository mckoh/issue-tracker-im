# %%
from issue_tracker import initialize_database
from issue_tracker import add_issue
from issue_tracker import get_issues

# %%
initialize_database()

add_issue(
    name="Staubsaugen",
    description="Putze die Wohnung",
    due_date="2026-07-30",
    priority=1
)

# %%
get_issues()
# Out:
# [(1, 'Einkaufen', 'Kaufe Eier und Milch', '2026-04-23', 1),
#  (2, 'Einkaufen', 'Kaufe Eier und Milch', '2026-04-23', 1),
#  (3, 'Einkaufen', 'Kaufe Eier und Milch', '2026-04-23', 1),
#  (4, 'Einkaufen', 'Kaufe Eier und Milch', '2026-04-23', 1),
#  (5, 'Staubsaugen', 'Kaufe Eier und Milch', '2026-04-23', 1),
#  (6, 'Staubsaugen', 'Putze die Wohnung', '2026-07-30', 1),
#  (7, 'Staubsaugen', 'Putze die Wohnung', '2026-07-30', 1)]

# %%
''
